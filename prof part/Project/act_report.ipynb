# %% [markdown]
# <a id='Analyzing'></a>
# ## Analyzing, and Visualizing Data

# %% [markdown]
# - The **mean dog rating** for the dataset is 1.06.
# - The **most dog rating** for the dataset is 2.6. it was for some cute dogs in one pic
#
# - The **mean FAVORITE count** for dogs is 8559.7
# - The **most FAVORITE tweet** for dogs is 132810
#
# - the **mean Retweet** on the other hand was 2976.17
# - The **most retweeted** tweet was retweeted 79515. times.

# %% [markdown]
# #### the most names used
# ![image.png](attachment:image.png)

# %% [markdown]
# #### number of tweets from the account over time
# ![image.png](attachment:image.png)
# we can see that the number of tweets is mostly steady and the same after January 2016

# %% [markdown]
# #### relationshipt between rating and number of retweets
# ![image.png](attachment:image.png)
# seems no relationship between rating and the number of retweets as people seen to retweet the pics any way

# %% [markdown]
# #### relationshipt between rating numerator and number of retweets
# ![image.png](attachment:image.png)
# same goes with rating numerator there is no relationship between rating_numerator and the number of retweets
